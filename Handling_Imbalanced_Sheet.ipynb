# %% [markdown]
# <a href="https://colab.research.google.com/github/ishnt/Data_science_stuff/blob/main/Handling_Imbalanced_Sheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Handling Imbalanced Sheet
#
# 1.Up Sampling
#
# 2.Down Sampling

# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(123)
samples=1000
ratio=0.8
class1=int(samples*ratio)
class2=samples-class1

# %%
class1,class2
# Out:
# (800, 200)

# %%
## CREATE MY DATAFRAME WITH IMBALANCED DATASET
df1 = pd.DataFrame({
    'feature_1': np.random.normal(loc=0, scale=1, size=class1),
    'feature_2': np.random.normal(loc=0, scale=1, size=class1),
    'target': [0] * class1
})

df2 = pd.DataFrame({
    'feature_1': np.random.normal(loc=2, scale=1, size=class2),
    'feature_2': np.random.normal(loc=2, scale=1, size=class2),
    'target': [1] * class2
})

# %%
df=pd.concat([df1,df2]).reset_index(drop=True)

# %%
df['target'].value_counts()
# Out:
# 0    800
# 1    200
# Name: target, dtype: int64

# %% [markdown]
# UPSAMPLING

# %%
major=df[df['target']==0]
minor=df[df['target']==1]

# %%
major
# Out:
#      feature_1  feature_2  target
# 0    -1.085631  -0.121167       0
# 1     0.997345  -2.008585       0
# 2     0.282978  -0.920647       0
# 3    -1.506295   0.168234       0
# 4    -0.578600  -1.319892       0
# ..         ...        ...     ...
# 795  -0.845644  -0.284553       0
# 796   0.911461   1.641404       0
# 797  -1.374497   1.152356       0
# 798  -0.547066  -0.601809       0
# 799  -0.000076  -1.215662       0
#
# [800 rows x 3 columns]

# %%
minor
# Out:
#      feature_1  feature_2  target
# 800   1.451582   1.699768       1
# 801   3.065383   1.367739       1
# 802   1.476078   1.795683       1
# 803   2.545988   2.213696       1
# 804   1.434120   3.033878       1
# ..         ...        ...     ...
# 995   1.996845   2.845701       1
# 996   1.569340   0.880077       1
# 997   1.853584   1.640703       1
# 998   3.160176   0.390305       1
# 999   1.358488   2.013570       1
#
# [200 rows x 3 columns]

# %%
from sklearn.utils import resample
minor_upsampled=resample(minor,replace=True, #Sample With replacement
         n_samples=len(major),
         random_state=42
        )

# %%
minor_upsampled
# Out:
#      feature_1  feature_2  target
# 902   1.226194   1.803557       1
# 979   3.482163   2.309863       1
# 892   2.231228   2.196570       1
# 814   2.024317   1.932170       1
# 906   2.992992   1.143350       1
# ..         ...        ...     ...
# 810   1.469828   2.995595       1
# 884   2.021456   1.712216       1
# 825   1.441176   2.193094       1
# 862   0.481674   2.111135       1
# 885   3.839348   3.011616       1
#
# [800 rows x 3 columns]

# %%
df=pd.concat([major,minor_upsampled]).reset_index(drop=True)

# %%
print(df['target'].value_counts())
# Out:
# 0    800
# 1    800
# Name: target, dtype: int64

# %% [markdown]
# DOWN-SAMPLING

# %%
np.random.seed(123)
samples=1000
ratio=0.8
class1=int(samples*ratio)
class2=samples-class1

## CREATE MY DATAFRAME WITH IMBALANCED DATASET
df1 = pd.DataFrame({
    'feature_1': np.random.normal(loc=0, scale=1, size=class1),
    'feature_2': np.random.normal(loc=0, scale=1, size=class1),
    'target': [0] * class1
})

df2 = pd.DataFrame({
    'feature_1': np.random.normal(loc=2, scale=1, size=class2),
    'feature_2': np.random.normal(loc=2, scale=1, size=class2),
    'target': [1] * class2
})
df=pd.concat([df1,df2]).reset_index(drop=True)

# %%
major=df[df['target']==0]
minor=df[df['target']==1]

# %%
from sklearn.utils import resample
major_downsampled=resample(major,replace=False, #Sample With replacement
         n_samples=len(minor),
         random_state=42
        )

# %%
major_downsampled
# Out:
#      feature_1  feature_2  target
# 696   1.072630  -1.439736       0
# 667   1.642183   0.682237       0
# 63   -1.326265  -1.830666       0
# 533   0.082595   0.648563       0
# 66    0.045490  -0.179589       0
# ..         ...        ...     ...
# 90    1.150206   0.161710       0
# 650   0.887766   0.874105       0
# 181   1.459589   0.024211       0
# 790  -1.360008   0.187258       0
# 554   1.158069  -0.183332       0
#
# [200 rows x 3 columns]

# %%
df=pd.concat([major_downsampled,minor]).reset_index(drop=True)

# %%
df
# Out:
#      feature_1  feature_2  target
# 0     1.072630  -1.439736       0
# 1     1.642183   0.682237       0
# 2    -1.326265  -1.830666       0
# 3     0.082595   0.648563       0
# 4     0.045490  -0.179589       0
# ..         ...        ...     ...
# 395   1.996845   2.845701       1
# 396   1.569340   0.880077       1
# 397   1.853584   1.640703       1
# 398   3.160176   0.390305       1
# 399   1.358488   2.013570       1
#
# [400 rows x 3 columns]

# %%
print(df['target'].value_counts())
# Out:
# 0    200
# 1    200
# Name: target, dtype: int64
