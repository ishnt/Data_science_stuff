# %% [markdown]
# <a href="https://colab.research.google.com/github/ishnt/Data_science_stuff/blob/main/CNN_implementation_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
pip install tensorflow[and-cuda]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('/content/Churn_Modelling.csv')

# %%
x=df.iloc[:,3:13]
y=df.iloc[:,13]

# %%
x
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
geo=pd.get_dummies(x['Geography'],drop_first=True)
g=pd.get_dummies(x['Gender'],drop_first=True)

# %%
x=x.drop(['Geography','Gender'],axis=1)

# %%
x
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary
# 0                  1        101348.88
# 1                  1        112542.58
# ...

# %%
pd.concat([x,geo,g],axis=1)
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0                  1        101348.88        0      0     0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=0)

# %%
from  sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train_scaled=scaler.fit_transform(x_train)

# %%
x_test_scaled=scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import ReLU
from tensorflow.keras.layers import Dropout

# %%
classifier=Sequential()

# %%
classifier.add(Dense(units=11,activation='relu'))

# %%
classifier.add(Dense(units=5,activation='relu'))
classifier.add(Dropout(0.2))

# %%
classifier.add(Dense(units=2,activation='relu'))
classifier.add(Dropout(0.3))

# %%
classifier.add(Dense(units=1,activation='sigmoid'))

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
import tensorflow as tf
early_stopping=tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0,
)

# %%
classifier.fit(x_train_scaled,y_train,validation_split=0.33,batch_size=10,epochs=1000,callbacks=early_stopping)
# Out:
# Epoch 1/1000
# 536/536 [==============================] - 6s 5ms/step - loss: 0.5733 - accuracy: 0.7830 - val_loss: 0.4852 - val_accuracy: 0.7955
# Epoch 2/1000
# 536/536 [==============================] - 2s 5ms/step - loss: 0.5034 - accuracy: 0.7953 - val_loss: 0.4597 - val_accuracy: 0.7955
# Epoch 3/1000
# 536/536 [==============================] - 3s 5ms/step - loss: 0.4833 - accuracy: 0.7962 - val_loss: 0.4513 - val_accuracy: 0.7955
# Epoch 4/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4751 - accuracy: 0.7962 - val_loss: 0.4478 - val_accuracy: 0.7955
# Epoch 5/1000
# 536/536 [==============================] - 5s 10ms/step - loss: 0.4715 - accuracy: 0.7962 - val_loss: 0.4430 - val_accuracy: 0.7955
# Epoch 6/1000
# 536/536 [==============================] - 5s 9ms/step - loss: 0.4662 - accuracy: 0.7962 - val_loss: 0.4418 - val_accuracy: 0.7955
# Epoch 7/1000
# ...

# %%
y_pred=classifier.predict(x_test_scaled)
y_pred=(y_pred>=0.5)
# Out:
# 63/63 [==============================] - 0s 2ms/step

# %%
 from sklearn.metrics import accuracy_score,classification_report
 score=accuracy_score(y_pred,y_test)
 print(score)
 print(classification_report(y_pred,y_test))
# Out:
# 0.7975
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89      2000
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.80      2000
#    macro avg       0.50      0.40      0.44      2000
# weighted avg       1.00      0.80      0.89      2000
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
